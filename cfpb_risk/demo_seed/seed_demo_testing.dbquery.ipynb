-- %%
SELECT current_status, COUNT(*)
FROM cfpb_risk.app.issues
GROUP BY current_status
ORDER BY 1;

SELECT current_status, COUNT(*)
FROM cfpb_risk.app.issues
GROUP BY current_status
ORDER BY 1;

SELECT event_type, COUNT(*)
FROM cfpb_risk.app.issue_events
GROUP BY event_type
ORDER BY 1;

SELECT issue_id, count(*)
FROM cfpb_risk.app.v_issue_queue
GROUP BY issue_id;
